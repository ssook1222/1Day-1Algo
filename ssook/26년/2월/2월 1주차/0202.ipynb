# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/ssook/26%EB%85%84/2%EC%9B%94/2%EC%9B%94%201%EC%A3%BC%EC%B0%A8/0202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 34297

# %%
# 입력 받기
M = int(input())  # 한 바퀴 도는데 걸리는 시간 (분)
K = int(input())  # 온도 (켈빈) - 사용되지 않음
C = int(input())  # 주차장을 도는 횟수

# 총 시간 계산
total_time = M * C

# 출력
print(total_time)
