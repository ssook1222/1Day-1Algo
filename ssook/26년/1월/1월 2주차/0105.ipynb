# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/ssook/26%EB%85%84/1%EC%9B%94/1%EC%9B%94%202%EC%A3%BC%EC%B0%A8/0105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 34362

# %%
# 고도 입력받기
altitude = float(input())

# 2050년 예상 고도 계산 (해수면 30cm = 0.3m 상승)
predicted_altitude = altitude - 0.3

# 결과 출력
print(predicted_altitude)
