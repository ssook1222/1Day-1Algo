# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 10205

# %%
for n in range(1, int(input()) + 1) :
    h = int(input())
    for i in input() :
        if i == "c" :
            h += 1
        else :
            h -= 1
    print(f"Data Set {n}:\n{h}\n")

# %% [markdown]
# ### 10205

# %%
print("FA")

# %% [markdown]
# ---

# %% [markdown]
# ## CodeTree

# %% [markdown]
# ### 몫과 나머지 2

# %%
x, y = map(int, input().split())
print('%d---%d' %(x//y, x%y))
