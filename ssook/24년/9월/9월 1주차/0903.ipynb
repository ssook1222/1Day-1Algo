# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 1167

# %%
import heapq
import sys

n = int(sys.stdin.readline())

left_heap = []   # max-heap to store the smaller half (negated values)
right_heap = []  # min-heap to store the larger half

for i in range(n):
    num = int(sys.stdin.readline())

    if len(left_heap) == len(right_heap):
        heapq.heappush(left_heap, -num)
    else:
        heapq.heappush(right_heap, num)

    if right_heap and right_heap[0] < -left_heap[0]:
        left_value = heapq.heappop(left_heap)
        right_value = heapq.heappop(right_heap)

        heapq.heappush(left_heap, -right_value)
        heapq.heappush(right_heap, -left_value)

    print(-left_heap[0])

# %% [markdown]
# ## CodeTree

# %% [markdown]
# ### 문자열 n번 출력하기

# %%
import sys

# 입력 받기
n = int(sys.stdin.readline().strip())

# n번 반복해서 출력하기
for _ in range(n):
    print("CodeTree Is Best!")
