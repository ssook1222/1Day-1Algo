# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 1167

# %%
import sys
from collections import deque

input = sys.stdin.readline

V = int(input().strip())
tree = [[] for _ in range(V + 1)]

# Read the tree edges and weights
for _ in range(V):
    line = list(map(int, input().split()))
    cnt_node = line[0]
    idx = 1
    while line[idx] != -1:
        adj_node, adj_cost = line[idx], line[idx + 1]
        tree[cnt_node].append((adj_node, adj_cost))
        idx += 2

def BFS(start):
    q = deque()
    q.append((start, 0))
    visited = [-1] * (V + 1)
    visited[start] = 0
    res = [0, 0]  # furthest node and its distance from start

    while q:
        cnt_node, cnt_dist = q.popleft()

        for adj_node, adj_dist in tree[cnt_node]:
            if visited[adj_node] == -1:
                cal_dist = cnt_dist + adj_dist
                q.append((adj_node, cal_dist))
                visited[adj_node] = cal_dist
                if res[1] < cal_dist:
                    res[0] = adj_node
                    res[1] = cal_dist

    return res

# Finding the tree diameter
point, _ = BFS(1)
print(BFS(point)[1])

# %% [markdown]
# ## CodeTree

# %% [markdown]
# ### n의 배수 출력

# %%
import sys

# 입력 받기
n = int(sys.stdin.readline().strip())

# n의 배수를 차례로 출력하기
for i in range(1, 16):
    print(n * i, end=" ")
print()  # 줄바꿈을 위한 추가 출력
