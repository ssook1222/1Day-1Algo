# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/ssook/25%EB%85%84/12%EC%9B%94/12%EC%9B%94%203%EC%A3%BC%EC%B0%A8/1219.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 6359

# %%
import math

def solve():
    t = int(input())

    for _ in range(t):
        n = int(input())

        # n 이하의 완전제곱수 개수 = floor(sqrt(n))
        escaped = int(math.sqrt(n))

        print(escaped)

solve()
