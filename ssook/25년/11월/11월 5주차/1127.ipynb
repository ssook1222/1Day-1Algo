# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/ssook/25%EB%85%84/11%EC%9B%94/11%EC%9B%94%205%EC%A3%BC%EC%B0%A8/1127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 12606

# %%
n = int(input())

for i in range(1, n + 1):
    line = input()
    words = line.split()
    reversed_words = words[::-1]
    print(f"Case #{i}: {' '.join(reversed_words)}")
