# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/ssook/25%EB%85%84/11%EC%9B%94/11%EC%9B%94%205%EC%A3%BC%EC%B0%A8/1125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BoJ

# %% [markdown]
# ### 34308

# %%
n, k = map(int, input().split())
requests = list(map(int, input().split()))

results = []

    if 2 * request <= n + 1:
        results.append(1)
    else:
        results.append(n)

print(' '.join(map(str, results)))
