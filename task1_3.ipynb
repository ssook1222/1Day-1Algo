# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/task1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 서울시 따릉이 이용정보 데이터

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bicycle/seoul_bi.csv')
df.head()
# Out:
#          대여일자  대여시간  대여소번호 대여구분코드 성별 연령대코드  이용건수    운동량   탄소량     이동거리  사용시간
# 0  2021-06-01     0   3541    정기권  F  ~10대     1   0.00  0.00     0.00     8
# 1  2021-06-01     0    765    정기권  F  ~10대     1  27.21  0.35  1526.81    19
# 2  2021-06-01     0   2637    정기권  F  ~10대     1  41.40  0.37  1608.56    18
# 3  2021-06-01     0   2919    정기권  F  ~10대     1   0.00  0.00     0.00    75
# 4  2021-06-01     0    549    정기권  F  ~10대     1  13.04  0.17   731.55     6

# %% [markdown]
# ### 31. 대여일자별 데이터의 수를 데이터프레임으로 출력하고, 가장 많은 데이터가 있는 날짜를 출력하라

# %%
display(pd.DataFrame(df.대여일자.value_counts()).sort_index())
print(pd.DataFrame(df.대여일자.value_counts()).head(1).index[0])
# Out:
#              대여일자
# 2021-06-01  48081
# 2021-06-02  56100
# 2021-06-03  18985
# 2021-06-04  56788
# 2021-06-05  52730
# 2021-06-06  47787
# 2021-06-07  52623
# 2021-06-08  55623
# 2021-06-09  54507
# 2021-06-10  36992
# 2021-06-11  52089
# 2021-06-12  48569
# 2021-06-13  43131
# 2021-06-14  54945
# 2021-06-04

# %% [markdown]
# ### 32. 각 일자의 요일을 표기하고 (‘Monday’ ~’Sunday’) ‘day_name’컬럼을 추가하고 이를 이용하여 각 요일별 이용 횟수의 총합을 데이터 프레임으로 출력하라

# %%
import datetime as dt

df.대여일자 = pd.to_datetime(df.대여일자)
df['day_name'] = df.대여일자.dt.strftime("%A")
pd.DataFrame(df['day_name'].value_counts())
# Out:
#            day_name
# Wednesday    110607
# Friday       108877
# Monday       107568
# Tuesday      103704
# Saturday     101299
# Sunday        90918
# Thursday      55977

# %% [markdown]
# ### 33. 각 요일별 가장 많이 이용한 대여소의 이용횟수와 대여소 번호를 데이터 프레임으로 출력하라

# %%
df_filter = df[['대여소번호', 'day_name']]
df_filter = df_filter.groupby(['day_name', '대여소번호']).size().sort_values(0, ascending=False).to_frame().reset_index().drop_duplicates('day_name', keep='first')
df_filter[['대여소번호',0]].reset_index(drop= True)
# Out:
# <ipython-input-69-613108bebd95>:2: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   df_filter = df_filter.groupby(['day_name', '대여소번호']).size().sort_values(0, ascending=False).to_frame().reset_index().drop_duplicates('day_name', keep='first')
#    대여소번호    0
# 0    502  378
# 1    502  372
# 2    502  282
# 3    502  277
# 4    502  267
# 5    502  242
# 6   2715  137

# %% [markdown]
# ### 34. 나이대별 대여구분 코드의 (일일권/전체횟수) 비율을 구한 후 가장 높은 비율을 가지는 나이대를 확인하라. 일일권의 경우 일일권 과 일일권(비회원)을 모두 포함하라

# %%
daily = df[df.대여구분코드.isin(['일일권','일일권(비회원)'])].연령대코드.value_counts().sort_index()
total = df.연령대코드.value_counts().sort_index()

ratio = pd.DataFrame((daily /total).sort_values(ascending=False)).head(1)
print(ratio.index)
# Out:
# Index(['~10대'], dtype='object')

# %% [markdown]
# ### 35. 연령대별 평균 이동거리를 구하여라

# %%
df[['연령대코드', '이동거리']].groupby(['연령대코드']).mean()
# Out:
#               이동거리
# 연령대코드
# 20대    3211.890552
# 30대    3341.443859
# 40대    3514.857416
# 50대    3593.668100
# 60대    3538.145737
# 70대~   3085.039641
# ~10대   2634.426279

# %% [markdown]
# ### 36. 연령대 코드가 20대인 데이터를 추출하고,이동거리값이 추출한 데이터의 이동거리값의 평균 이상인 데이터를 추출한다.최종 추출된 데이터를 대여일자, 대여소 번호 순서로 내림차순 정렬 후 1행부터 200행까지의 탄소량의 평균을 소숫점 3째 자리까지 구하여라

# %%
df_20 = df[df['연령대코드'] == '20대']
df_20 = df_20[df_20.이동거리 >= df_20.이동거리.mean()]

df_20['탄소량'] = df_20['탄소량'].astype('float')
round(df_20.sort_values(['대여일자', '대여소번호'], ascending = False)[1:200].mean().탄소량,3)
# Out:
# <ipython-input-72-756c25ff5eec>:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   round(df_20.sort_values(['대여일자', '대여소번호'], ascending = False)[1:200].mean().탄소량,3)
# <ipython-input-72-756c25ff5eec>:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   round(df_20.sort_values(['대여일자', '대여소번호'], ascending = False)[1:200].mean().탄소량,3)
# 1.611

# %% [markdown]
# ### 37. 6월 7일 ~10대의 “이용건수”의 중앙값은?

# %%
df['대여일자'] = pd.to_datetime(df['대여일자'])
df_0607 = df[(df.연령대코드 =='~10대') & (df.대여일자 ==pd.to_datetime('2021-06-07'))]

df_0607.이용건수.median()
# Out:
# 1.0

# %% [markdown]
# ### 38. 평일 (월~금) 출근 시간대(오전 6,7,8시)의 대여소별 이용 횟수를 구해서 데이터 프레임 형태로 표현한 후 각 대여시간별 이용 횟수의 상위 3개 대여소와 이용횟수를 출력하라

# %%
raw = df[(df.대여일자.dt.weekday == 1) & (df.대여시간.isin([6,7,8]))].groupby(['대여시간','대여소번호'])
raw.size().to_frame('이용 횟수').sort_values(['대여시간','이용 횟수'],ascending=False).groupby('대여시간').head(3)
# Out:
#             이용 횟수
# 대여시간 대여소번호
# 8    646       22
#      2701      21
#      247       20
# 7    259       18
#      2107      15
#      230       13
# 6    185        8
#      1028       8
#      2744       8

# %% [markdown]
# ### 39. 이동거리의 평균 이상의 이동거리 값을 가지는 데이터를 추출하여 추출데이터의 이동거리의 표본표준편차 값을 구하여라

# %%
df[df.이동거리 >= df.이동거리.mean()].이동거리.std()
# Out:
# 5092.139707505356

# %% [markdown]
# ### 40. 남성(‘M’ or ‘m’)과 여성(‘F’ or ‘f’)의 이동거리값의 평균값을 구하여라

# %%
df_man = df[df['성별'].isin(['M', 'm'])]
df_woman = df[(df.성별.isin(['F', 'f']))]

df_man.이동거리.mean(), df_woman.이동거리.mean()
# Out:
# (3209.1108714530546, 3468.5750252981957)
