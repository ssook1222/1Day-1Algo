# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/1Day-1Algo/blob/master/bigdata-analysist-certificate/preprocessing/preprocessing1_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/seoul_pm.csv')

# %%
import datetime

def change_date(x):
    hour = x.split(':')[1]
    date = x.split(":")[0]

    if hour =='24':
        hour ='00:00:00'

        FinalDate = pd.to_datetime(date+" "+hour) +datetime.timedelta(days=1)

    else:
        hour = hour +':00:00'
        FinalDate = pd.to_datetime(date+" "+hour)

    return FinalDate

df['(년-월-일:시)'] = df['(년-월-일:시)'].apply(change_date)

# %%
df['dayName'] = df['(년-월-일:시)'].dt.day_name()

# %% [markdown]
# ### 81. 날짜 컬럼을 index로 만들어라

# %%
df = df.set_index('(년-월-일:시)')

# %% [markdown]
# ### 82. 데이터를 주단위로 뽑아서 최소, 최대, 평균, 표준편차를 구하여라

# %%
df.resample('W').agg(['min','max', 'mean', 'std'])
# Out:
# <ipython-input-5-fc4ad601bc52>:1: FutureWarning: ['PM10등급', 'PM2.5등급', '오존등급', '이산화질소등급', '일산화탄소등급', '아황산가스등급', 'dayName'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.resample('W').agg(['min','max', 'mean', 'std'])
#             PM10                                 PM2.5                    \
#              min     max        mean         std   min    max       mean
# (년-월-일:시)
# 2021-03-28   6.0   160.0   72.747368   43.345462   4.0  113.0  44.705263
# 2021-04-04   3.0   598.0   97.148810  129.911976   1.0  120.0  23.168675
# 2021-04-11  17.0   102.0   41.059524   16.325911   7.0   70.0  21.761905
# 2021-04-18   3.0   367.0   48.180723   43.254468   2.0   38.0  17.066265
# 2021-04-25  17.0   126.0   55.119048   26.659936   7.0   61.0  26.392857
# 2021-05-02   3.0    97.0   40.612121   24.813103   1.0   43.0  16.644578
# ...

# %% [markdown]
# 인덱스가 날짜일 경우, `resample('W')`을 사용하여 주단위로 데이터를 뽑아서 집계함수를 적용할 수 있음.

# %% [markdown]
# ## 06.Pivot

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/under5MortalityRate.csv')

# %% [markdown]
# ### 83. Indicator을 삭제하고 First Tooltip 컬럼에서 신뢰구간에 해당하는 표현을 지워라

# %%
df['First Tooltip'] = df['First Tooltip'].map(lambda x: x.split('[')[0])
df
# Out:
#           Location  Period                                          Indicator  \
# 0      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 1      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 2      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 3      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# 4      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# ...            ...     ...                                                ...
# 29994  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29995  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29996  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29997  Timor-Leste    2001  Under-five mortality rate (probability of dyin...
# 29998  Timor-Leste    2001  Under-five mortality rate (probability of dyin...
#
#              Dim1 First Tooltip
# ...

# %% [markdown]
# 특정 열에 값을 변경하기 위해서는 **`데이터프레임.map(lambda x: 적용할 함수 형태)` **로 작업해주면 됨.

# %% [markdown]
# ### 84. 년도가 2015년 이상, Dim1이 Both sexes인 케이스만 추출하라

# %%
target = df[(df['Period']>=2015) & (df['Dim1'] == 'Both sexes')]
target
# Out:
#           Location  Period                                          Indicator  \
# 0      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 3      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# 6      Afghanistan    2017  Under-five mortality rate (probability of dyin...
# 9      Afghanistan    2016  Under-five mortality rate (probability of dyin...
# 12     Afghanistan    2015  Under-five mortality rate (probability of dyin...
# ...            ...     ...                                                ...
# 29943  Timor-Leste    2019  Under-five mortality rate (probability of dyin...
# 29946  Timor-Leste    2018  Under-five mortality rate (probability of dyin...
# 29949  Timor-Leste    2017  Under-five mortality rate (probability of dyin...
# 29952  Timor-Leste    2016  Under-five mortality rate (probability of dyin...
# 29955  Timor-Leste    2015  Under-five mortality rate (probability of dyin...
#
#              Dim1 First Tooltip
# ...

# %% [markdown]
# ### 85. 84번 문제에서 추출한 데이터로 아래와 같이 나라에 따른 년도별 사망률을 데이터 프레임화 하라

# %%
target.pivot(index='Location',columns='Period',values='First Tooltip')
# Out:
# Period                                       2015    2016    2017    2018  \
# Location
# Afghanistan                                70.44   67.57   64.94   62.54
# Albania                                     9.57    9.42    9.42    9.53
# Algeria                                    25.18   24.79   24.32   23.81
# Andorra                                     3.53    3.37    3.22    3.09
# Angola                                      88.2   84.21   80.62   77.67
# ...                                           ...     ...     ...     ...
# Syrian Arab Republic                       23.18   23.27   22.97   22.11
# Tajikistan                                 37.75   36.82   35.81    34.8
# Thailand                                    10.8   10.32    9.86    9.42
# The former Yugoslav Republic of Macedonia  12.97   11.97    9.94    7.83
# Timor-Leste                                50.76   49.01   47.27   45.62
#
# Period                                       2019
# Location
# ...

# %% [markdown]
# ~에 따른 ~에 대한 비율이나 데이터를 구하기 위해서는 `pivot`을 사용하는 것이 유리함.

# %% [markdown]
# ### 86. Dim1에 따른 년도별 사망비율의 평균을 구하라

# %%
df.pivot_table(index='Dim1',columns='Period',values='First Tooltip', aggfunc = 'mean')
# Out:
# <ipython-input-19-b2b8476b08c4>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(index='Dim1',columns='Period',values='First Tooltip', aggfunc = 'mean')
# Empty DataFrame
# Columns: []
# Index: [Both sexes, Female, Male]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/winter.csv')

# %% [markdown]
# ### 87.데이터에서 한국 KOR 데이터만 추출하라

# %%
df_kor = df[df['Country'] == 'KOR']

# %% [markdown]
# ### 88. 한국 올림픽 메달리스트 데이터에서 년도에 따른 medal 갯수를 데이터프레임화 하라

# %%
df_kor2 = df_kor.pivot_table(index = 'Year', columns= 'Medal', aggfunc = 'size').fillna(0)
df_kor2
# Out:
# Medal  Bronze  Gold  Silver
# Year
# 1992      1.0   5.0     1.0
# 1994      1.0   8.0     1.0
# 1998      2.0   6.0     4.0
# 2002      0.0   5.0     2.0
# 2006      2.0  14.0     3.0
# 2010      2.0   6.0    10.0
# 2014      2.0   7.0     5.0

# %% [markdown]
# ### 89. 전체 데이터에서 sport종류에 따른 성별수를 구하여라

# %%
df.pivot_table(index='Sport', columns='Gender', aggfunc='size')
# Out:
# Gender       Men  Women
# Sport
# Biathlon     270    150
# Bobsleigh    416     36
# Curling       97     75
# Ice Hockey  1231    305
# Luge         135     45
# Skating      665    564
# Skiing      1130    651

# %% [markdown]
# ### 90. 전체 데이터에서 Discipline종류에 따른 따른 Medal수를 구하여라

# %%
df.pivot_table(index='Discipline', columns='Medal', aggfunc='size')
# Out:
# Medal                      Bronze  Gold  Silver
# Discipline
# Alpine Skiing                 141   143     144
# Biathlon                      139   140     141
# Bobsleigh                     147   134     141
# Cross Country Skiing          263   264     262
# Curling                        56    58      58
# Figure skating                118   122     119
# Freestyle Skiing               34    34      34
# Ice Hockey                    512   510     514
# Luge                           60    62      58
# Nordic Combined                55    55      55
# Short Track Speed Skating      96    97      97
# Skeleton                       10    10      10
# Ski Jumping                    68    69      70
# Snowboard                      30    30      30
# Speed skating                 190   193     197
